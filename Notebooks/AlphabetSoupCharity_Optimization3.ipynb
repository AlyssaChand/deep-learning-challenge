# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop non-beneficial ID columns, 'EIN'
application_df = application_df.drop(columns=['EIN'])
application_df.head()
# Out:
#                                        NAME APPLICATION_TYPE  \
# 0              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# NAME                      19568
# APPLICATION_TYPE             17
# AFFILIATION                   6
# CLASSIFICATION               71
# USE_CASE                      5
# ORGANIZATION                  4
# STATUS                        2
# INCOME_AMT                    9
# SPECIAL_CONSIDERATIONS        2
# ASK_AMT                    8747
# IS_SUCCESSFUL                 2
# dtype: int64

# %%
# Look at NAME value counts to identify and replace with "Other"
name = application_df['NAME'].value_counts()
name
# Out:
# NAME
# PARENT BOOSTER USA INC                                                  1260
# TOPS CLUB INC                                                            765
# UNITED STATES BOWLING CONGRESS INC                                       700
# WASHINGTON STATE UNIVERSITY                                              492
# AMATEUR ATHLETIC UNION OF THE UNITED STATES INC                          408
#                                                                         ...
# ST LOUIS SLAM WOMENS FOOTBALL                                              1
# AIESEC ALUMNI IBEROAMERICA CORP                                            1
# WEALLBLEEDRED ORG INC                                                      1
# AMERICAN SOCIETY FOR STANDARDS IN MEDIUMSHIP & PSYCHICAL INVESTIGATI       1
# WATERHOUSE CHARITABLE TR                                                   1
# Name: count, Length: 19568, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
cutoff_value = 20
application_types_to_replace = name[name < cutoff_value].index.tolist()
# Replace in dataframe
for app in application_types_to_replace:
    application_df['NAME'] = application_df['NAME'].replace(app,"Other")

# Check to make sure replacement was successful
application_df['NAME'].value_counts()
# Out:
# NAME
# Other                                             22409
# PARENT BOOSTER USA INC                             1260
# TOPS CLUB INC                                       765
# UNITED STATES BOWLING CONGRESS INC                  700
# WASHINGTON STATE UNIVERSITY                         492
#                                                   ...
# AMERICAN IRIS SOCIETY                                21
# ARIZONA FEDERATION OF GARDEN CLUBS                   21
# GENERAL FEDERATION OF WOMENS CLUBS ARIZONA INC       20
# DISABLED AMERICAN VETERANS AUXILIARY INC             20
# TEXAS MASTER GARDENER ASSOCIATION INC                20
# Name: count, Length: 122, dtype: int64

# %%
# Look at CLASSIFICATION value counts to identify and replace with "Other"
classification = application_df['CLASSIFICATION'].value_counts()
classification
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_greater1 = classification[classification > 1]
classification_greater1
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
cutoff_value = 1918
classifications_to_replace = classification[classification <= cutoff_value].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure replacement was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# Other     6062
# C1200     4837
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
numeric_application_df = pd.get_dummies(application_df)
numeric_application_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  NAME_AIR FORCE ASSOCIATION  \
# 0           1      5000              1                       False
# 1           1    108590              1                       False
# 2           1      5000              0                       False
# 3           1      6692              1                       False
# 4           1    142590              1                       False
# ...       ...       ...            ...                         ...
# 34294       1      5000              0                       False
# 34295       1      5000              0                       False
# 34296       1      5000              0                       False
# 34297       1      5000              1                       False
# 34298       1  36500179              0                       False
#
#        NAME_ALABAMA FEDERATION OF WOMENS CLUBS  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ...                                        ...
# 34294                                    False
# 34295                                    False
# 34296                                    False
# 34297                                    False
# 34298                                    False
#
#        NAME_ALABAMA TREASURE FOREST ASSOCIATION  NAME_ALPHA PHI SIGMA  \
# 0                                         False                 False
# 1                                         False                 False
# 2                                         False                 False
# 3                                         False                 False
# 4                                         False                 False
# ...                                         ...                   ...
# 34294                                     False                 False
# 34295                                     False                 False
# 34296                                     False                 False
# 34297                                     False                 False
# 34298                                     False                 False
#
#        NAME_ALPHA PHI SIGMA INC  NAME_ALTRUSA INTERNATIONAL FOUNDATION INC  \
# 0                         False                                      False
# 1                         False                                      False
# 2                         False                                      False
# 3                         False                                      False
# 4                         False                                      False
# ...                         ...                                        ...
# 34294                     False                                      False
# 34295                     False                                      False
# 34296                     False                                      False
# 34297                     False                                      False
# 34298                     False                                      False
#
#        NAME_AMATEUR ATHLETIC UNION OF THE UNITED STATES  ...  \
# 0                                                 False  ...
# 1                                                 False  ...
# 2                                                 False  ...
# 3                                                 False  ...
# 4                                                 False  ...
# ...                                                 ...  ...
# 34294                                             False  ...
# 34295                                             False  ...
# 34296                                             False  ...
# 34297                                             False  ...
# 34298                                             False  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                  False                   False                     False
# 1                   True                   False                     False
# 2                  False                   False                     False
# 3                  False                    True                     False
# 4                  False                   False                      True
# ...                  ...                     ...                       ...
# 34294              False                   False                     False
# 34295              False                   False                     False
# 34296              False                   False                     False
# 34297              False                   False                     False
# 34298              False                   False                     False
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                   False             False                   False
# 1                   False             False                   False
# 2                   False             False                   False
# 3                   False             False                   False
# 4                   False             False                   False
# ...                   ...               ...                     ...
# 34294               False             False                   False
# 34295               False             False                   False
# 34296               False             False                   False
# 34297               False             False                   False
# 34298               False              True                   False
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                False              False                      True
# 1                False              False                      True
# 2                False              False                      True
# 3                False              False                      True
# 4                False              False                      True
# ...                ...                ...                       ...
# 34294            False              False                      True
# 34295            False              False                      True
# 34296            False              False                      True
# 34297            False              False                      True
# 34298            False              False                      True
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                         False
# 1                         False
# 2                         False
# 3                         False
# 4                         False
# ...                         ...
# 34294                     False
# 34295                     False
# 34296                     False
# 34297                     False
# 34298                     False
#
# [34299 rows x 172 columns]

# %%
# Split our preprocessed data into our features and target arrays
X = numeric_application_df.drop(columns=['IS_SUCCESSFUL'])
y = numeric_application_df['IS_SUCCESSFUL']

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = X_train.shape[1]
hidden_nodes_layer1 =  80
hidden_nodes_layer2 = 40
hidden_nodes_layer3 = 20

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="sigmoid"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation='sigmoid'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                13760
#
#  dense_1 (Dense)             (None, 40)                3240
#
#  dense_2 (Dense)             (None, 20)                820
#
#  dense_3 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 17841 (69.69 KB)
# Trainable params: 17841 (69.69 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Create a callback that saves the model's weights every five epochs
checkpoint_path = "checkpoints/weights.{epoch:02d}.hdf5"
cp_callback = ModelCheckpoint(filepath=checkpoint_path,
                              save_weights_only=True,
                              save_freq=5 * len(X_train_scaled) // 32)

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100, callbacks=[cp_callback])
# Out:
# Epoch 1/100
# 804/804 [==============================] - 7s 5ms/step - loss: 0.5076 - accuracy: 0.7535
# Epoch 2/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4676 - accuracy: 0.7744
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4625 - accuracy: 0.7764
# Epoch 4/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4599 - accuracy: 0.7776
# Epoch 5/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4580 - accuracy: 0.7781
# Epoch 6/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4564 - accuracy: 0.7782
# Epoch 7/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4557 - accuracy: 0.7784
# Epoch 8/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4539 - accuracy: 0.7795
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4531 - accuracy: 0.7792
# Epoch 10/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4516 - accuracy: 0.7807
# Epoch 11/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4510 - accuracy: 0.7821
# Epoch 12/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4506 - accuracy: 0.7813
# Epoch 13/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4494 - accuracy: 0.7817
# Epoch 14/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.